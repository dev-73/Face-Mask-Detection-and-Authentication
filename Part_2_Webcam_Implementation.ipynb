# %%
import torch
import torch.nn as nn
import torch.optim as optim
from torch.optim import lr_scheduler
import numpy as np
import torchvision
from torchvision import datasets, models, transforms
import matplotlib.pyplot as plt
import time
import os
import pandas as pd
from sklearn.model_selection import train_test_split
import shutil
import time
import copy
from PIL import Image
import glob
import cv2


filepath = 'C:/Users/smit gandhi/Desktop/FACE mask temp/maskmodel3_GoogleNet.pth'
model = torch.load(filepath)


class_names = ['with_mask',
 'without_mask'
]



def process_image(image):
    ''' Scales, crops, and normalizes a PIL image for a PyTorch model,
        returns an Numpy array
    '''
    
    # TODO: Process a PIL image for use in a PyTorch model
    #pil_image = Image.open(image)
    pil_image = image
   
    image_transforms = transforms.Compose([
        transforms.Resize(256),
        transforms.CenterCrop(224),
        transforms.ToTensor(),
        transforms.Normalize([0.485, 0.456, 0.406], [0.229, 0.224, 0.225])
    ])
    
    img = image_transforms(pil_image)
    return img
    
    


def classify_face(image):
    device = torch.device("cpu")
    image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
    #im_pil = image.fromarray(image)
    #image = np.asarray(im)
    im = Image.fromarray(image)
    image = process_image(im)
    print('image_processed')
    img = image.unsqueeze_(0)
    img = image.float()

    model.eval()
    model.cpu()
    output = model(image)
    print(output,'##############output###########')
    _, predicted = torch.max(output, 1)
    print(predicted.data[0],"predicted")


    classification1 = predicted.data[0]
    index = int(classification1)
    print(class_names[index])
    return class_names[index]


'''
if __name__ == '__main__':
    #map_location=torch.device('cpu')
    image = cv2.imread('C:/Users/smit gandhi/Desktop/Maskthe faceimages/maksssksksss6.png')
    label = classify_face(image)
    print("the label is", label)
    '''
# Out:
# '\nif __name__ == \'__main__\':\n    #map_location=torch.device(\'cpu\')\n    image = cv2.imread(\'C:/Users/smit gandhi/Desktop/Maskthe faceimages/maksssksksss6.png\')\n    label = classify_face(image)\n    print("the label is", label)\n    '

# %%
import cv2
import os
from keras.models import load_model
import numpy as np
from pygame import mixer
import time
# from lebel import classify_face


mixer.init()
sound = mixer.Sound('C:/Users/smit gandhi/Desktop/FaceMask_detection_alarm.wav')


#face = cv2.CascadeClassifier('/media/preeth/Data/prajna_files/Drowsiness_detection/haar_cascade_files/haarcascade_frontalface_alt.xml')
cap = cv2.VideoCapture(0)
font = cv2.FONT_HERSHEY_COMPLEX_SMALL
score=0
thicc=2
#faces = face.detectMultiScale(gray,minNeighbors=5,scaleFactor=1.1,minSize=(25,25))
while(True):
    ret, frame = cap.read()
    height,width = frame.shape[:2]
    label = classify_face(frame)
    if(label == 'with_mask'):
        print("No Beep")
    else:
        sound.play()
        print("Beep")   
    cv2.putText(frame,str(label),(100,height-20), font, 1,(255,255,255),1,cv2.LINE_AA)
    cv2.imshow('frame',frame)
    if cv2.waitKey(1) & 0xFF == ord('q'):
        break
cap.release()
cv2.destroyAllWindows()
# Out:
# pygame 2.0.1 (SDL 2.0.14, Python 3.8.3)
# Hello from the pygame community. https://www.pygame.org/contribute.html
# image_processed
# tensor([[-0.8293,  0.6067]], grad_fn=<AddmmBackward>) ##############output###########
# tensor(1) predicted
# without_mask
# Beep
# image_processed
# tensor([[-0.9018,  0.6162]], grad_fn=<AddmmBackward>) ##############output###########
# tensor(1) predicted
# without_mask
# Beep
# image_processed
# tensor([[-0.8559,  0.5329]], grad_fn=<AddmmBackward>) ##############output###########
# tensor(1) predicted
# without_mask
# Beep
# image_processed
# tensor([[-0.9509,  0.6792]], grad_fn=<AddmmBackward>) ##############output###########
# tensor(1) predicted
# without_mask
# Beep
# image_processed
# tensor([[-0.8576,  0.6195]], grad_fn=<AddmmBackward>) ##############output###########
# tensor(1) predicted
# without_mask
# Beep
# image_processed
# tensor([[-0.8162,  0.6223]], grad_fn=<AddmmBackward>) ##############output###########
# tensor(1) predicted
# without_mask
# Beep
# image_processed
# tensor([[-0.7413,  0.5219]], grad_fn=<AddmmBackward>) ##############output###########
# tensor(1) predicted
# without_mask
# Beep
# image_processed
# tensor([[-0.8631,  0.6202]], grad_fn=<AddmmBackward>) ##############output###########
# tensor(1) predicted
# without_mask
# Beep
# image_processed
# tensor([[-0.7938,  0.5823]], grad_fn=<AddmmBackward>) ##############output###########
# tensor(1) predicted
# without_mask
# Beep
# image_processed
# tensor([[-0.7521,  0.5889]], grad_fn=<AddmmBackward>) ##############output###########
# tensor(1) predicted
# without_mask
# Beep
# image_processed
# tensor([[-0.8404,  0.6347]], grad_fn=<AddmmBackward>) ##############output###########
# tensor(1) predicted
# without_mask
# Beep
# image_processed
# tensor([[-0.8127,  0.5886]], grad_fn=<AddmmBackward>) ##############output###########
# tensor(1) predicted
# without_mask
# Beep
# image_processed
# tensor([[-0.7687,  0.5683]], grad_fn=<AddmmBackward>) ##############output###########
# tensor(1) predicted
# without_mask
# Beep
# image_processed
# tensor([[-0.8233,  0.5709]], grad_fn=<AddmmBackward>) ##############output###########
# tensor(1) predicted
# without_mask
# Beep
# image_processed
# tensor([[-0.8840,  0.8051]], grad_fn=<AddmmBackward>) ##############output###########
# tensor(1) predicted
# without_mask
# Beep
# image_processed
# tensor([[-0.8250,  0.6203]], grad_fn=<AddmmBackward>) ##############output###########
# tensor(1) predicted
# without_mask
# Beep
# image_processed
# tensor([[-0.8592,  0.6294]], grad_fn=<AddmmBackward>) ##############output###########
# tensor(1) predicted
# without_mask
# Beep
# image_processed
# tensor([[-0.8051,  0.5530]], grad_fn=<AddmmBackward>) ##############output###########
# tensor(1) predicted
# without_mask
# Beep
# image_processed
# tensor([[-0.8112,  0.5109]], grad_fn=<AddmmBackward>) ##############output###########
# tensor(1) predicted
# without_mask
# Beep
# image_processed
# tensor([[-0.6824,  0.4065]], grad_fn=<AddmmBackward>) ##############output###########
# tensor(1) predicted
# without_mask
# Beep
# image_processed
# tensor([[-0.7776,  0.3834]], grad_fn=<AddmmBackward>) ##############output###########
# tensor(1) predicted
# without_mask
# Beep
# image_processed
# tensor([[-0.5417,  0.2541]], grad_fn=<AddmmBackward>) ##############output###########
# tensor(1) predicted
# without_mask
# Beep
# image_processed
# tensor([[-0.7196,  0.3453]], grad_fn=<AddmmBackward>) ##############output###########
# tensor(1) predicted
# without_mask
# Beep
# image_processed
# tensor([[-1.0042,  0.5799]], grad_fn=<AddmmBackward>) ##############output###########
# tensor(1) predicted
# without_mask
# Beep
# image_processed
# tensor([[-0.6845,  0.2500]], grad_fn=<AddmmBackward>) ##############output###########
# tensor(1) predicted
# without_mask
# Beep
# image_processed
# tensor([[-0.9052,  0.4771]], grad_fn=<AddmmBackward>) ##############output###########
# tensor(1) predicted
# without_mask
# Beep
# image_processed
# tensor([[-0.6011,  0.2242]], grad_fn=<AddmmBackward>) ##############output###########
# tensor(1) predicted
# without_mask
# Beep
# image_processed
# tensor([[-0.7547,  0.3318]], grad_fn=<AddmmBackward>) ##############output###########
# tensor(1) predicted
# without_mask
# Beep
# image_processed
# tensor([[-0.6730,  0.2546]], grad_fn=<AddmmBackward>) ##############output###########
# tensor(1) predicted
# without_mask
# Beep
# image_processed
# tensor([[-0.5211,  0.1781]], grad_fn=<AddmmBackward>) ##############output###########
# tensor(1) predicted
# without_mask
# Beep
# image_processed
# tensor([[-0.6621,  0.2997]], grad_fn=<AddmmBackward>) ##############output###########
# tensor(1) predicted
# without_mask
# Beep
# image_processed
# tensor([[-0.8144,  0.3355]], grad_fn=<AddmmBackward>) ##############output###########
# tensor(1) predicted
# without_mask
# Beep
# image_processed
# tensor([[-0.6857,  0.3047]], grad_fn=<AddmmBackward>) ##############output###########
# tensor(1) predicted
# without_mask
# Beep
# image_processed
# tensor([[-0.5044,  0.0842]], grad_fn=<AddmmBackward>) ##############output###########
# tensor(1) predicted
# without_mask
# Beep
# image_processed
# tensor([[-0.7668,  0.3499]], grad_fn=<AddmmBackward>) ##############output###########
# tensor(1) predicted
# without_mask
# Beep
# image_processed
# tensor([[-0.6416,  0.2556]], grad_fn=<AddmmBackward>) ##############output###########
# tensor(1) predicted
# without_mask
# Beep
# image_processed
# tensor([[-0.6145,  0.2026]], grad_fn=<AddmmBackward>) ##############output###########
# tensor(1) predicted
# without_mask
# Beep
# image_processed
# tensor([[-0.7923,  0.3477]], grad_fn=<AddmmBackward>) ##############output###########
# tensor(1) predicted
# without_mask
# Beep
# image_processed
# tensor([[-0.6659,  0.2883]], grad_fn=<AddmmBackward>) ##############output###########
# tensor(1) predicted
# without_mask
# Beep
# image_processed
# tensor([[-0.5455,  0.2669]], grad_fn=<AddmmBackward>) ##############output###########
# tensor(1) predicted
# without_mask
# Beep
# image_processed
# tensor([[-0.5327,  0.2542]], grad_fn=<AddmmBackward>) ##############output###########
# tensor(1) predicted
# without_mask
# Beep
# image_processed
# tensor([[-0.5927,  0.2824]], grad_fn=<AddmmBackward>) ##############output###########
# tensor(1) predicted
# without_mask
# Beep
# image_processed
# tensor([[-0.5998,  0.2741]], grad_fn=<AddmmBackward>) ##############output###########
# tensor(1) predicted
# without_mask
# Beep
# image_processed
# tensor([[-0.1617, -0.1704]], grad_fn=<AddmmBackward>) ##############output###########
# tensor(0) predicted
# with_mask
# No Beep
# image_processed
# tensor([[-0.7857,  0.3181]], grad_fn=<AddmmBackward>) ##############output###########
# tensor(1) predicted
# without_mask
# Beep
# image_processed
# tensor([[-0.8809,  0.3604]], grad_fn=<AddmmBackward>) ##############output###########
# tensor(1) predicted
# without_mask
# Beep
# image_processed
# tensor([[-0.8756,  0.3585]], grad_fn=<AddmmBackward>) ##############output###########
# tensor(1) predicted
# without_mask
# Beep
# image_processed
# tensor([[-0.6619,  0.2158]], grad_fn=<AddmmBackward>) ##############output###########
# tensor(1) predicted
# without_mask
# Beep
# image_processed
# tensor([[-0.8572,  0.3757]], grad_fn=<AddmmBackward>) ##############output###########
# tensor(1) predicted
# without_mask
# Beep
# image_processed
# tensor([[-0.9318,  0.4371]], grad_fn=<AddmmBackward>) ##############output###########
# tensor(1) predicted
# without_mask
# Beep
# image_processed
# tensor([[-0.9811,  0.4601]], grad_fn=<AddmmBackward>) ##############output###########
# tensor(1) predicted
# without_mask
# Beep
# image_processed
# tensor([[-0.6160,  0.1915]], grad_fn=<AddmmBackward>) ##############output###########
# tensor(1) predicted
# without_mask
# Beep
# image_processed
# tensor([[-0.4737,  0.0312]], grad_fn=<AddmmBackward>) ##############output###########
# tensor(1) predicted
# without_mask
# Beep
# image_processed
# tensor([[-0.
], grad_fn=<AddmmBackward>) ##############output###########
# tensor(1) predicted
# without_mask
# Beep
# image_processed
# tensor([[-1.5578,  1.2501]], grad_fn=<AddmmBackward>) ##############output###########
# tensor(1) predicted
# without_mask
# Beep
# image_processed
# tensor([[-1.0968,  0.8283]], grad_fn=<AddmmBackward>) ##############output###########
# tensor(1) predicted
# without_mask
# Beep
# image_processed
# tensor([[-0.8428,  0.5750]], grad_fn=<AddmmBackward>) ##############output###########
# tensor(1) predicted
# without_mask
# Beep
# image_processed
# tensor([[-0.9273,  0.6258]], grad_fn=<AddmmBackward>) ##############output###########
# tensor(1) predicted
# without_mask
# Beep
# image_processed
# tensor([[-1.7122,  1.3840]], grad_fn=<AddmmBackward>) ##############output###########
# tensor(1) predicted
# without_mask
# Beep
# image_processed
# tensor([[-1.4391,  1.1919]], grad_fn=<AddmmBackward>) ##############output###########
# tensor(1) predicted
# without_mask
# Beep
# image_processed
# tensor([[-1.5057,  1.1919]], grad_fn=<AddmmBackward>) ##############output###########
# tensor(1) predicted
# without_mask
# Beep
# image_processed
# tensor([[-1.8388,  1.4727]], grad_fn=<AddmmBackward>) ##############output###########
# tensor(1) predicted
# without_mask
# Beep
# image_processed
# tensor([[-1.6320,  1.3110]], grad_fn=<AddmmBackward>) ##############output###########
# tensor(1) predicted
# without_mask
# Beep
# image_processed
# tensor([[-1.7609,  1.4499]], grad_fn=<AddmmBackward>) ##############output###########
# tensor(1) predicted
# without_mask
# Beep
# image_processed
# tensor([[-1.9287,  1.5663]], grad_fn=<AddmmBackward>) ##############output###########
# tensor(1) predicted
# without_mask
# Beep
# image_processed
# tensor([[-2.0537,  1.7122]], grad_fn=<AddmmBackward>) ##############output###########
# tensor(1) predicted
# without_mask
# Beep
# image_processed
# tensor([[-1.9500,  1.6589]], grad_fn=<AddmmBackward>) ##############output###########
# tensor(1) predicted
# without_mask
# Beep
# image_processed
# tensor([[-1.9390,  1.6551]], grad_fn=<AddmmBackward>) ##############output###########
# tensor(1) predicted
# without_mask
# Beep
# image_processed
# tensor([[-1.9048,  1.5195]], grad_fn=<AddmmBackward>) ##############output###########
# tensor(1) predicted
# without_mask
# Beep
# image_processed
# tensor([[-1.7887,  1.4566]], grad_fn=<AddmmBackward>) ##############output###########
# tensor(1) predicted
# without_mask
# Beep
# image_processed
# tensor([[-1.4602,  1.1934]], grad_fn=<AddmmBackward>) ##############output###########
# tensor(1) predicted
# without_mask
# Beep
# image_processed
# tensor([[-1.7234,  1.4496]], grad_fn=<AddmmBackward>) ##############output###########
# tensor(1) predicted
# without_mask
# Beep
# image_processed
# tensor([[-1.5263,  1.3088]], grad_fn=<AddmmBackward>) ##############output###########
# tensor(1) predicted
# without_mask
# Beep
# image_processed
# tensor([[-1.3228,  1.0761]], grad_fn=<AddmmBackward>) ##############output###########
# tensor(1) predicted
# without_mask
# Beep
# image_processed
# tensor([[-1.5120,  1.2561]], grad_fn=<AddmmBackward>) ##############output###########
# tensor(1) predicted
# without_mask
# Beep
# image_processed
# tensor([[-1.7262,  1.4666]], grad_fn=<AddmmBackward>) ##############output###########
# tensor(1) predicted
# without_mask
# Beep
# image_processed
# tensor([[-1.3771,  1.1281]], grad_fn=<AddmmBackward>) ##############output###########
# tensor(1) predicted
# without_mask
# Beep
# image_processed
# tensor([[-1.6334,  1.3045]], grad_fn=<AddmmBackward>) ##############output###########
# tensor(1) predicted
# without_mask
# Beep
# image_processed
# tensor([[-1.6015,  1.2617]], grad_fn=<AddmmBackward>) ##############output###########
# tensor(1) predicted
# without_mask
# Beep
# image_processed
# tensor([[-1.3226,  1.0939]], grad_fn=<AddmmBackward>) ##############output###########
# tensor(1) predicted
# without_mask
# Beep
# image_processed
# tensor([[-1.4292,  1.1355]], grad_fn=<AddmmBackward>) ##############output###########
# tensor(1) predicted
# without_mask
# Beep
# image_processed
# tensor([[-1.6577,  1.3741]], grad_fn=<AddmmBackward>) ##############output###########
# tensor(1) predicted
# without_mask
# Beep
# image_processed
# tensor([[-1.6298,  1.1982]], grad_fn=<AddmmBackward>) ##############output###########
# tensor(1) predicted
# without_mask
# Beep
# image_processed
# tensor([[-2.1338,  1.6529]], grad_fn=<AddmmBackward>) ##############output###########
# tensor(1) predicted
# without_mask
# Beep
# image_processed
# tensor([[-1.8462,  1.4164]], grad_fn=<AddmmBackward>) ##############output###########
# tensor(1) predicted
# without_mask
# Beep
# image_processed
# tensor([[-2.5562,  2.0028]], grad_fn=<AddmmBackward>) ##############output###########
# tensor(1) predicted
# without_mask
# Beep
# image_processed
# tensor([[-2.5344,  2.0048]], grad_fn=<AddmmBackward>) ##############output###########
# tensor(1) predicted
# without_mask
# Beep
# image_processed
# tensor([[-2.2691,  1.6977]], grad_fn=<AddmmBackward>) ##############output###########
# tensor(1) predicted
# without_mask
# Beep
# image_processed
# tensor([[-1.9111,  1.5816]], grad_fn=<AddmmBackward>) ##############output###########
# tensor(1) predicted
# without_mask
# Beep
# image_processed
# tensor([[-1.9773,  1.6239]], grad_fn=<AddmmBackward>) ##############output###########
# tensor(1) predicted
# without_mask
# Beep
# image_processed
# tensor([[-1.7275,  1.3655]], grad_fn=<AddmmBackward>) ##############output###########
# tensor(1) predicted
# without_mask
# Beep
# image_processed
# tensor([[-1.6873,  1.3437]], grad_fn=<AddmmBackward>) ##############output###########
# tensor(1) predicted
# without_mask
# Beep
# image_processed
# tensor([[-2.2959,  1.9073]], grad_fn=<AddmmBackward>) ##############output###########
# tensor(1) predicted
# without_mask
# Beep
# image_processed
# tensor([[-2.2239,  1.7066]], grad_fn=<AddmmBackward>) ##############output###########
# tensor(1) predicted
# without_mask
# Beep
# image_processed
# tensor([[-2.2646,  1.7098]], grad_fn=<AddmmBackward>) ##############output###########
# tensor(1) predicted
# without_mask
# Beep
# image_processed
# tensor([[-1.8161,  1.4443]], grad_fn=<AddmmBackward>) ##############output###########
# tensor(1) predicted
# without_mask
# Beep
# image_processed
# tensor([[-1.9574,  1.4984]], grad_fn=<AddmmBackward>) ##############output###########
# tensor(1) predicted
# without_mask
# Beep
# image_processed
# tensor([[-2.4414,  1.9288]], grad_fn=<AddmmBackward>) ##############output###########
# tensor(1) predicted
# without_mask
# Beep
# image_processed
# tensor([[-2.2204,  1.7331]], grad_fn=<AddmmBackward>) ##############output###########
# tensor(1) predicted
# without_mask
# Beep
# image_processed
# tensor([[-1.9478,  1.4923]], grad_fn=<AddmmBackward>) ##############output###########
# tensor(1) predicted
# without_mask
# Beep
# image_processed
# tensor([[-1.4492,  1.1264]], grad_fn=<AddmmBackward>) ##############output###########
# tensor(1) predicted
# without_mask
# Beep
# image_processed
# tensor([[-2.0776,  1.5839]], grad_fn=<AddmmBackward>) ##############output###########
# tensor(1) predicted
# without_mask
# Beep
# image_processed
# tensor([[-1.3902,  0.9886]], grad_fn=<AddmmBackward>) ##############output###########
# tensor(1) predicted
# without_mask
# Beep
# image_processed
# tensor([[-1.4204,  1.0174]], grad_fn=<AddmmBackward>) ##############output###########
# tensor(1) predicted
# without_mask
# Beep
# image_processed
# tensor([[-1.1997,  0.9208]], grad_fn=<AddmmBackward>) ##############output###########
# tensor(1) predicted
# without_mask
# Beep
# image_processed
# tensor([[-1.3395,  1.0972]], grad_fn=<AddmmBackward>) ##############output###########
# tensor(1) predicted
# without_mask
# Beep
# image_processed
# tensor([[-1.3954,  1.1152]], grad_fn=<AddmmBackward>) ##############output###########
# tensor(1) predicted
# without_mask
# Beep
# image_processed
# tensor([[-1.3437,  1.0431]], grad_fn=<AddmmBackward>) ##############output###########
# tensor(1) predicted
# without_mask
# Beep
# image_processed
# tensor([[-1.1101,  0.8351]], grad_fn=<AddmmBackward>) ##############output###########
# tensor(1) predicted
# without_mask
# Beep
# image_processed
# tensor([[-1.2078,  0.9050]], grad_fn=<AddmmBackward>) ##############output###########
# tensor(1) predicted
# without_mask
# Beep
# image_processed
# tensor([[-1.2768,  0.9764]], grad_fn=<AddmmBackward>) ##############output###########
# tensor(1) predicted
# without_mask
# Beep
# image_processed
# tensor([[-1.2325,  0.9443]], grad_fn=<AddmmBackward>) ##############output###########
# tensor(1) predicted
# without_mask
# Beep
# image_processed
# tensor([[-0.7744,  0.5952]], grad_fn=<AddmmBackward>) ##############output###########
# tensor(1) predicted
# without_mask
# Beep
# image_processed
# tensor([[-1.1508,  0.8974]], grad_fn=<AddmmBackward>) ##############output###########
# tensor(1) predicted
# without_mask
# Beep
# image_processed
# tensor([[-1.2131,  0.8615]], grad_fn=<AddmmBackward>) ##############output###########
# tensor(1) predicted
# without_mask
# Beep
# image_processed
# tensor([[-0.8539,  0.5280]], grad_fn=<AddmmBackward>) ##############output###########
# tensor(1) predicted
# without_mask
# Beep
# image_processed
# tensor([[-0.9477,  0.6267]], grad_fn=<AddmmBackward>) ##############output###########
# tensor(1) predicted
# without_mask
# Beep
# image_processed
# tensor([[-1.2574,  0.8936]], grad_fn=<AddmmBackward>) ##############output###########
# tensor(1) predicted
# without_mask
# Beep
# image_processed
# tensor([[-1.5179,  1.2228]], grad_fn=<AddmmBackward>) ##############output###########
# tensor(1) predicted
# without_mask
# Beep
# image_processed
# tensor([[-2.0717,  1.6351]], grad_fn=<AddmmBackward>) ##############output###########
# tensor(1) predicted
# without_mask
# Beep
# image_processed
# tensor([[-1.9470,  1.6170]], grad_fn=<AddmmBackward>) ##############output###########
# tensor(1) predicted
# without_mask
# Beep
# image_processed
# tensor([[-1.9792,  1.5912]], grad_fn=<AddmmBackward>) ##############output###########
# tensor(1) predicted
# without_mask
# Beep
# image_processed
# tensor([[-1.7175,  1.3524]], grad_fn=<AddmmBackward>) ##############output###########
# tensor(1) predicted
# without_mask
# Beep
# image_processed
# tensor([[-1.9762,  1.5636]], grad_fn=<AddmmBackward>) ##############output###########
# tensor(1) predicted
# without_mask
# Beep
# image_processed
# tensor([[-2.0730,  1.5744]], grad_fn=<AddmmBackward>) ##############output###########
# tensor(1) predicted
# without_mask
# Beep
# image_processed
# tensor([[-1.9213,  1.4163]], grad_fn=<AddmmBackward>) ##############output###########
# tensor(1) predicted
# without_mask
# Beep
# image_processed
# tensor([[-2.2636,  1.7222]], grad_fn=<AddmmBackward>) ##############output###########
# tensor(1) predicted
# without_mask
# Beep
# image_processed
# tensor([[-2.0759,  1.6285]], grad_fn=<AddmmBackward>) ##############output###########
# tensor(1) predicted
# without_mask
# Beep
# image_processed
# tensor([[-2.4201,  1.8509]], grad_fn=<AddmmBackward>) ##############output###########
# tensor(1) predicted
# without_mask
# Beep
# image_processed
# tensor([[-2.4993,  1.9275]], grad_fn=<AddmmBackward>) ##############output###########
# tensor(1) predicted
# without_mask
# Beep
# image_processed
# tensor([[-2.5826,  2.0439]], grad_fn=<AddmmBackward>) ##############output###########
# tensor(1) predicted
# without_mask
# Beep
# image_processed
# tensor([[-2.8409,  2.3894]], grad_fn=<AddmmBackward>) ##############output###########
# tensor(1) predicted
# without_mask
# Beep
# image_processed
# tensor([[-2.5258,  2.0141]], grad_fn=<AddmmBackward>) ##############output###########
# tensor(1) predicted
# without_mask
# Beep
# image_processed
# tensor([[-2.4092,  1.8747]], grad_fn=<AddmmBackward>) ##############output###########
# tensor(1) predicted
# without_mask
# Beep
# image_processed
# tensor([[-2.6061,  2.0409]], grad_fn=<AddmmBackward>) ##############output###########
# tensor(1) predicted
# without_mask
# Beep
# image_processed
# tensor([[-2.7098,  2.1670]], grad_fn=<AddmmBackward>) ##############output###########
# tensor(1) predicted
# without_mask
# Beep
# image_processed
# tensor([[-2.3580,  1.8297]], grad_fn=<AddmmBackward>) ##############output###########
# tensor(1) predicted
# without_mask
# Beep
# image_processed
# tensor([[-2.4115,  1.9421]], grad_fn=<AddmmBackward>) ##############output###########
# tensor(1) predicted
# without_mask
# Beep
# image_processed
# tensor([[-2.7857,  2.2634]], grad_fn=<AddmmBackward>) ##############output###########
# tensor(1) predicted
# without_mask
# Beep
# image_processed
# tensor([[-2.7959,  2.1724]], grad_fn=<AddmmBackward>) ##############output###########
# tensor(1) predicted
# without_mask
# Beep
# image_processed
# tensor([[-2.6581,  2.0626]], grad_fn=<AddmmBackward>) ##############output###########
# tensor(1) predicted
# without_mask
# Beep
# image_processed
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-2-8112efb0a52a> in <module>
#      21     ret, frame = cap.read()
#      22     height,width = frame.shape[:2]
# ---> 23     label = classify_face(frame)
#      24     if(label == 'with_mask'):
#      25         print("No Beep")
#
# <ipython-input-1-140194600399> in classify_face(image)
#      64     model.eval()
#      65     model.cpu()
# ---> 66     output = model(image)
#      67     print(output,'##############output###########')
#      68     _, predicted = torch.max(output, 1)
#
# ~\anaconda3\lib\site-packages\torch\nn\modules\module.py in _call_impl(self, *input, **kwargs)
#     887             result = self._slow_forward(*input, **kwargs)
#     888         else:
# --> 889             result = self.forward(*input, **kwargs)
#     890         for hook in itertools.chain(
#     891                 _global_forward_hooks.values(),
#
# ~\anaconda3\lib\site-packages\torchvision\models\googlenet.py in forward(self, x)
#     206     def forward(self, x: Tensor) -> GoogLeNetOutputs:
#     207         x = self._transform_input(x)
# --> 208         x, aux1, aux2 = self._forward(x)
#     209         aux_defined = self.training and self.aux_logits
#     210         if torch.jit.is_scripting():
#
# ~\anaconda3\lib\site-packages\torchvision\models\googlenet.py in _forward(self, x)
#     152         x = self.conv3(x)
#     153         # N x 192 x 56 x 56
# --> 154         x = self.maxpool2(x)
#     155
#     156         # N x 192 x 28 x 28
#
# ~\anaconda3\lib\site-packages\torch\nn\modules\module.py in _call_impl(self, *input, **kwargs)
#     887             result = self._slow_forward(*input, **kwargs)
#     888         else:
# --> 889             result = self.forward(*input, **kwargs)
#     890         for hook in itertools.chain(
#     891                 _global_forward_hooks.values(),
#
# ~\anaconda3\lib\site-packages\torch\nn\modules\pooling.py in forward(self, input)
#     160
#     161     def forward(self, input: Tensor) -> Tensor:
# --> 162         return F.max_pool2d(input, self.kernel_size, self.stride,
#     163                             self.padding, self.dilation, self.ceil_mode,
#     164                             self.return_indices)
#
# ~\anaconda3\lib\site-packages\torch\_jit_internal.py in fn(*args, **kwargs)
#     363             return if_true(*args, **kwargs)
#     364         else:
# --> 365             return if_false(*args, **kwargs)
#     366
#     367     if if_true.__doc__ is None and if_false.__doc__ is not None:
#
# ~\anaconda3\lib\site-packages\torch\nn\functional.py in _max_pool2d(input, kernel_size, stride, padding, dilation, ceil_mode, return_indices)
#     657     if stride is None:
#     658         stride = torch.jit.annotate(List[int], [])
# --> 659     return torch.max_pool2d(input, kernel_size, stride, padding, dilation, ceil_mode)
#     660
#     661
#
# KeyboardInterrupt:
